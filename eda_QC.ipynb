# %%
import pandas as pd

# Load the CSV file
file_path = 'India_MDP_reports\India MDP Report - MASTER - Quality Consciousness Workshop.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset to understand its structure
data.head(), data.columns
# Out:
# (               Unnamed: 0 Unnamed: 1                     Unnamed: 2  \
#  0               Name\n \n   Gender\n                          Email
#  1            Heena Khatri     Female     counselorheena28@gmail.com
#  2  Prakash Chandra Kumhar       Male  purchase@alakhnayanmandir.org
#  3             Upma Mishra     Female        upmamishra398@gmail.com
#  4   Sonia Dharmendra Jena     Female          soniajena12@gmail.com
#
#                   Unnamed: 3 Unnamed: 4  \
#  0               Designation       Role
#  1                 Counselor        AOP
#  2  Purchase & Store Manager      Admin
#  3         Patient Counselor        AOP
#  4         HR and Admin Head      Admin
#
#                                            Unnamed: 5 Unnamed: 6  \
#  0                                           Hospital    Country
#  1                   Alakh Nayan Mandir Eye Institute      India
#  2                   Alakh Nayan Mandir Eye Institute      India
# ...

# %%
# Load the data again, this time with the correct header row
data = pd.read_csv(file_path, header=1)

# Display the cleaned-up data to check the headers and initial rows
data.head(), data.columns
# Out:
# (                Name\n \n Gender\n                          Email  \
#  0            Heena Khatri   Female     counselorheena28@gmail.com
#  1  Prakash Chandra Kumhar     Male  purchase@alakhnayanmandir.org
#  2             Upma Mishra   Female        upmamishra398@gmail.com
#  3   Sonia Dharmendra Jena   Female          soniajena12@gmail.com
#  4         Shailendra Arya     Male          optomshailu@gmail.com
#
#                  Designation   Role  \
#  0                 Counselor    AOP
#  1  Purchase & Store Manager  Admin
#  2         Patient Counselor    AOP
#  3         HR and Admin Head  Admin
#  4                   Manager  Admin
#
#                                              Hospital Country           Batch  \
#  0                   Alakh Nayan Mandir Eye Institute   India  India MDP 2023
#  1                   Alakh Nayan Mandir Eye Institute   India  India MDP 2023
#  2                   Alakh Nayan Mandir Eye institute   India  India MDP 2023
# ...

# %%
# Rename columns for easier reference
data.columns = [
    'Name', 'Gender', 'Email', 'Designation', 'Role', 'Hospital',
    'Country', 'Batch',
    'Completion_1st_2nd_Session',
    'Feedback_Day1_14May2024', 'Feedback_Day2_28May2024', 'Feedback_Day3_4Jun2024', 
    'Feedback_Day4_18Jun2024', 'Feedback_Day5_25Jun2024', 'Feedback_Day6_2Jul2024',
    'Feedback_Day7_9Jul2024', 'Feedback_Day8_16Jul2024', 'Feedback_Day9_23Jul2024',
    'Feedback_Day1_14May2024_dup', 'Feedback_Day2_28May2024_dup', 'Feedback_Day3_4Jun2024_dup',
    'Feedback_Day4_18Jun2024_dup', 'Feedback_Day5_25Jun2024_dup', 'Feedback_Day6_2Jul2024_dup',
    'Feedback_Day7_9Jul2024_dup', 'Feedback_Day8_16Jul2024_dup', 'Feedback_Day9_23Jul2024_dup',
    'Feedback_Day10_6Aug2024', 'Overall_Attendance', 'Overall_Attendance_Percentage',
    'Feedback_Day2_28May2024_triple', 'Feedback_Day5_25Jun2024_triple', 'Feedback_Day6_2Jul2024_triple',
    'Feedback_Day8_16Jul2024_triple', 'Feedback_Day9_23Jul2024_triple',
    'Assignment_Received', 'Assignment_Completion_Percentage',
    'Completion_4th_Session', 'Completion_7th_Session', 'Completion_9th_Session',
    'Completion_10th_Session'
]

# Handle missing data by filling with a placeholder or dropping unnecessary columns/rows
data_cleaned = data.fillna({
    'Feedback_Day1_14May2024': 0,
    'Feedback_Day2_28May2024': 0,
    'Feedback_Day3_4Jun2024': 0,
    'Feedback_Day4_18Jun2024': 0,
    'Feedback_Day5_25Jun2024': 0,
    'Feedback_Day6_2Jul2024': 0,
    'Feedback_Day7_9Jul2024': 0,
    'Feedback_Day8_16Jul2024': 0,
    'Feedback_Day9_23Jul2024': 0,
    'Feedback_Day10_6Aug2024': 0,
    'Overall_Attendance_Percentage': 0,
    'Assignment_Completion_Percentage': 0
})

# Let's display the first few rows of the cleaned dataset to verify the changes
data_cleaned.head()
# Out:
#                      Name  Gender                          Email  \
# 0            Heena Khatri  Female     counselorheena28@gmail.com
# 1  Prakash Chandra Kumhar    Male  purchase@alakhnayanmandir.org
# 2             Upma Mishra  Female        upmamishra398@gmail.com
# 3   Sonia Dharmendra Jena  Female          soniajena12@gmail.com
# 4         Shailendra Arya    Male          optomshailu@gmail.com
#
#                 Designation   Role  \
# 0                 Counselor    AOP
# 1  Purchase & Store Manager  Admin
# 2         Patient Counselor    AOP
# 3         HR and Admin Head  Admin
# 4                   Manager  Admin
#
#                                             Hospital Country           Batch  \
# 0                   Alakh Nayan Mandir Eye Institute   India  India MDP 2023
# 1                   Alakh Nayan Mandir Eye Institute   India  India MDP 2023
# 2                   Alakh Nayan Mandir Eye institute   India  India MDP 2023
# ...

# %%
import matplotlib.pyplot as plt

# Generate descriptive statistics for numeric columns
descriptive_stats = data_cleaned[['Feedback_Day1_14May2024', 'Feedback_Day2_28May2024', 
                                  'Feedback_Day3_4Jun2024', 'Feedback_Day4_18Jun2024',
                                  'Feedback_Day5_25Jun2024', 'Feedback_Day6_2Jul2024',
                                  'Feedback_Day7_9Jul2024', 'Feedback_Day8_16Jul2024',
                                  'Feedback_Day9_23Jul2024', 'Feedback_Day10_6Aug2024',
                                  'Overall_Attendance_Percentage', 'Assignment_Completion_Percentage',
                                  'Completion_4th_Session', 'Completion_7th_Session',
                                  'Completion_9th_Session', 'Completion_10th_Session']].describe()

# Plot distribution of overall attendance percentage
plt.figure(figsize=(10, 6))
plt.hist(data_cleaned['Overall_Attendance_Percentage'], bins=10, color='blue', edgecolor='black')
plt.title('Distribution of Overall Attendance Percentage')
plt.xlabel('Attendance Percentage')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Plot distribution of feedback scores for Day 1
plt.figure(figsize=(10, 6))
plt.hist(data_cleaned['Feedback_Day1_14May2024'], bins=5, color='green', edgecolor='black')
plt.title('Distribution of Feedback Scores for Day 1')
plt.xlabel('Feedback Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
from IPython.display import display

# Assuming 'new_descriptive_stats' is your DataFrame with descriptive statistics
display(descriptive_stats)
# Out:
#        Feedback_Day1_14May2024  Feedback_Day2_28May2024  \
# count                45.000000                45.000000
# mean                  1.976444                 2.546222
# std                   2.452358                 2.341475
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 4.000000
# 75%                   5.000000                 5.000000
# max                   5.000000                 5.000000
#
#        Feedback_Day3_4Jun2024  Feedback_Day4_18Jun2024  \
# count               45.000000                45.000000
# mean                 1.459778                 1.835333
# std                  2.211043                 2.293706
# min                  0.000000                 0.000000
# 25%                  0.000000                 0.000000
# 50%                  0.000000                 0.000000
# 75%                  4.000000                 4.000000
# ...

# %% [markdown]
# ### Summary of the Data
#
# 1. **Feedback Scores:**
#    - The feedback scores were collected over multiple days, with each session having its own score.
#    - The average feedback score for the first session (Day 1) is approximately 1.98, with a standard deviation of 2.45. This suggests a wide variation in the feedback received, with some participants giving low scores and others giving higher scores.
#    - The feedback scores tend to decrease over subsequent sessions, with a similar level of variability. For instance, the average score for Day 9 is about 1.79 with a standard deviation of 2.26.
#    - The minimum feedback score for each day is 0, indicating some participants did not provide feedback or rated the session very poorly.
#
# 2. **Overall Attendance Percentage:**
#    - The average attendance percentage is approximately 67.4%, with a standard deviation of 36.7%. This indicates that while some participants attended all or most sessions, others had much lower attendance.
#    - The distribution of attendance is broad, with some participants having as low as 0% attendance.
#
# 3. **Assignment Completion:**
#    - The average assignment completion percentage across participants is 25.9%, with a standard deviation of 32.5%. This suggests that many participants did not complete their assignments, while a few completed them fully.
#    - The distribution of assignment completion shows that a significant number of participants did not complete any assignments.
#
# 4. **Session Completion Percentages:**
#    - The completion percentage for various sessions after the 4th, 7th, 9th, and 10th sessions varies widely. The mean completion rate after the 10th session is around 20.7%, with some participants completing 100% and others not completing any part of the course.
#
# ### Analysis and Insights
#
# 1. **Wide Variation in Engagement:**
#    - There is significant variation in both feedback and attendance, indicating that while some participants were highly engaged, others were not as involved. This could be due to various factors such as the relevance of the content, the delivery method, or external commitments.
#
# 2. **Decreasing Feedback Scores Over Time:**
#    - The decrease in feedback scores over time might suggest a decline in participant satisfaction or engagement as the workshop progresses. This could be due to content fatigue, the increasing complexity of the material, or a disconnect between participant expectations and the workshop content.
#
# 3. **Low Assignment Completion:**
#    - The low assignment completion rates suggest that participants might have found the assignments challenging, irrelevant, or time-consuming. Alternatively, it could reflect a lack of motivation or support for completing the assignments.
#
# 4. **Attendance Patterns:**
#    - With some participants having very low or even zero attendance, it could indicate that the timing or scheduling of the sessions was inconvenient, or that there was a lack of interest or perceived value in attending the sessions.
#
# ### Supporting Statistics
#
# - **Mean Feedback Scores** across all days range from approximately 1.5 to 2.5, indicating a generally low level of positive feedback.
# - **Standard Deviation** of Feedback Scores is high (around 2.2 to 2.5), showing a broad spread in the participant responses.
# - **Attendance Mean:** 67.4%, but with a high standard deviation (36.7%), pointing to inconsistent attendance.
# - **Assignment Completion Mean:** 25.9%, indicating a low overall completion rate, with some outliers who completed all assignments.

# %%
# Perform the same analysis for the first workshop data (previously loaded as 'data_cleaned')
# First, we'll group by 'Hospital' and calculate the mean feedback, completion rates, and assignment completion for each

workshop2_grouped = data_cleaned.groupby('Hospital').agg({
    'Feedback_Day1_14May2024': 'mean',
    'Feedback_Day2_28May2024': 'mean',
    'Feedback_Day3_4Jun2024': 'mean',
    'Feedback_Day4_18Jun2024': 'mean',
    'Feedback_Day5_25Jun2024': 'mean',
    'Feedback_Day6_2Jul2024': 'mean',
    'Feedback_Day7_9Jul2024': 'mean',
    'Feedback_Day8_16Jul2024': 'mean',
    'Feedback_Day9_23Jul2024': 'mean',
    'Assignment_Completion_Percentage': 'mean',
    'Completion_4th_Session': 'mean',
    'Completion_7th_Session': 'mean',
    'Completion_9th_Session': 'mean',
    'Completion_10th_Session': 'mean'
})

# Calculate the overall average for feedback and completion rates for each hospital
workshop2_grouped['Avg_Feedback_Score'] = workshop2_grouped[['Feedback_Day1_14May2024', 'Feedback_Day2_28May2024', 'Feedback_Day3_4Jun2024', 'Feedback_Day4_18Jun2024', 'Feedback_Day5_25Jun2024', 'Feedback_Day6_2Jul2024', 'Feedback_Day7_9Jul2024', 'Feedback_Day8_16Jul2024', 'Feedback_Day9_23Jul2024']].mean(axis=1)
workshop2_grouped['Avg_Completion_Rate'] = workshop2_grouped[['Completion_4th_Session', 'Completion_7th_Session', 'Completion_9th_Session', 'Completion_10th_Session']].mean(axis=1)

# Add the overall assignment completion percentage
workshop2_grouped['Avg_Assignment_Completion'] = workshop2_grouped['Assignment_Completion_Percentage']

# Combine metrics into a single performance score (e.g., weighted sum or average)
workshop2_grouped['Performance_Score'] = workshop2_grouped[['Avg_Feedback_Score', 'Avg_Completion_Rate', 'Avg_Assignment_Completion']].mean(axis=1)

# Sort by performance score to find the top-performing hospital
top_hospital_workshop2 = workshop2_grouped.sort_values('Performance_Score', ascending=False).head(1)

top_hospital_workshop2
# Out:
#                                      Feedback_Day1_14May2024  \
# Hospital
# SILIGURI GREATER LIONS EYE HOSPITAL                      5.0
#
#                                      Feedback_Day2_28May2024  \
# Hospital
# SILIGURI GREATER LIONS EYE HOSPITAL                      5.0
#
#                                      Feedback_Day3_4Jun2024  \
# Hospital
# SILIGURI GREATER LIONS EYE HOSPITAL                     0.0
#
#                                      Feedback_Day4_18Jun2024  \
# Hospital
# SILIGURI GREATER LIONS EYE HOSPITAL                      5.0
#
#                                      Feedback_Day5_25Jun2024  \
# Hospital
# SILIGURI GREATER LIONS EYE HOSPITAL                      0.0
#
#                                      Feedback_Day6_2Jul2024  \
# Hospital
# SILIGURI GREATER LIONS EYE HOSPITAL                     0.0
#
#                                      Feedback_Day7_9Jul2024  \
# Hospital
# SILIGURI GREATER LIONS EYE HOSPITAL                     0.0
#
# ...

# %% [markdown]
# To determine which hospital performs the best based on the provided data from both workshops, we can analyze several factors such as:
#
# 1. **Average Feedback Scores**: Higher average feedback scores would indicate better perceived quality by participants.
# 2. **Completion Rates**: Higher completion rates might indicate better engagement and retention.
# 3. **Assignment Completion**: A higher percentage of assignments completed could reflect better participant involvement.
#
# I'll calculate these metrics for each hospital/organization and compare them to identify which one performs the best.
#
# Let me start by analyzing the data from both workshops to identify the top-performing hospital. I'll combine the results and provide a summary.
#
# ### Top-Performing Hospital in the Quality Consciousness Workshop
#
# For the Quality Consciousness Workshop, the analysis shows that **SILIGURI GREATER LIONS EYE HOSPITAL** is the top-performing hospital based on the following metrics:
#
# - **Average Feedback Score:** 2.22
# - **Average Completion Rate:** 66.75%
# - **Assignment Completion Percentage:** 66.67%
# - **Overall Performance Score:** 45.21
#
# ### Summary of Performance:
# - The hospital showed relatively good performance, especially in the later sessions, with solid completion rates and assignment completion. However, the feedback scores were somewhat lower compared to the top hospital in the Communication Skills Workshop.
#
# ### Overall Comparison Across Both Workshops
#
# - **Sitapur Eye Hospital Trust, Sitapur** (from the Communication Skills Workshop) achieved a higher overall performance score (64.89) compared to **SILIGURI GREATER LIONS EYE HOSPITAL** (45.21) from the Quality Consciousness Workshop.
# - This indicates that **Sitapur Eye Hospital Trust, Sitapur** performed better overall, especially with higher feedback scores and perfect assignment completion.
#
# Thus, across both workshops, **Sitapur Eye Hospital Trust, Sitapur** appears to be the best-performing hospital based on the combined metrics of feedback, session completion rates, and assignment completion.

# %%
# Prepare the data for attendance distribution
attendance_columns = [
    'Completion_4th_Session', 'Completion_7th_Session', 
    'Completion_9th_Session', 'Completion_10th_Session'
]

# We will calculate the mean attendance for each of these sessions
mean_attendance = data_cleaned[attendance_columns].mean()

# Create a bar chart for attendance distribution
plt.figure(figsize=(10, 6))
mean_attendance.plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title('Average Attendance Distribution Across Sessions')
plt.xlabel('Session')
plt.ylabel('Average Attendance Percentage')
plt.xticks(ticks=range(len(attendance_columns)), labels=['4th Session', '7th Session', '9th Session', '10th Session'], rotation=45)
plt.tight_layout()

# Save the attendance distribution bar chart
plt.savefig('attendance_distribution.png')
plt.show()
